# %%
from unicore.data import LMDBDataset
import pandas as pd
import concurrent.futures

train_data_path = "/scratch/ssd004/datasets/cellxgene/3d_molecule_data/ligands/train.lmdb"

dataset = LMDBDataset(train_data_path)

print(f"Loaded {len(dataset)} rows from lmdb training set")
# Out:
# Loaded 18837320 rows from lmdb training set

# %%
dataset[1378138].keys()
# Out:
# dict_keys(['atoms', 'coordinates', 'smi'])

# %%
# 1378138, 2230322, 11464458
dataset[1378138]
# Out:
# {'atoms': ['C',
#   'C',
#   'C',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'C',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'C',
#   'C',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H'],
#  'coordinates': [array([[ 0.47853562, -2.7253337 ,  0.07118345],
#          [ 1.2618402 , -1.4393185 ,  0.01563211],
#          [ 2.6700883 , -1.594471  , -0.03544389],
#          [ 3.5100634 , -0.49573776,  0.00920905],
#          [ 4.859935  , -0.67895424, -0.02704749],
#          [ 2.9775078 ,  0.7701418 ,  0.12744647],
#          [ 3.8357663 ,  1.831126  ,  0.22982377],
#          [ 1.5926367 ,  0.9331804 ,  0.15659569],
#          [ 1.1567521 ,  2.2561371 ,  0.3799032 ],
#          [-0.15901338,  2.55709   ,  0.68117636],
#          [-0.47495955,  3.6517425 ,  1.1280073 ],
#          [-1.155264  ,  1.5142894 ,  0.34859166],
#          [-2.506908  ,  1.9020075 ,  0.35500726],
# ...

# %%
dataset[2230322]
# Out:
# {'atoms': ['C',
#   'C',
#   'C',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'C',
#   'C',
#   'O',
#   'C',
#   'O',
#   'C',
#   'C',
#   'C',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H',
#   'H'],
#  'coordinates': [array([[ 0.47853562, -2.7253337 ,  0.07118345],
#          [ 1.2618402 , -1.4393185 ,  0.01563211],
#          [ 2.6700883 , -1.594471  , -0.03544389],
#          [ 3.5100634 , -0.49573776,  0.00920905],
#          [ 4.859935  , -0.67895424, -0.02704749],
#          [ 2.9775078 ,  0.7701418 ,  0.12744647],
#          [ 3.8357663 ,  1.831126  ,  0.22982377],
#          [ 1.5926367 ,  0.9331804 ,  0.15659569],
#          [ 1.1567521 ,  2.2561371 ,  0.3799032 ],
#          [-0.15901338,  2.55709   ,  0.68117636],
#          [-0.47495955,  3.6517425 ,  1.1280073 ],
#          [-1.155264  ,  1.5142894 ,  0.34859166],
#          [-2.506908  ,  1.9020075 ,  0.35500726],
# ...

# %%
dataset[11464458]["coordinates"]
# Out:
# [array([[ 0.47853562, -2.7253337 ,  0.07118345],
#         [ 1.2618402 , -1.4393185 ,  0.01563211],
#         [ 2.6700883 , -1.594471  , -0.03544389],
#         [ 3.5100634 , -0.49573776,  0.00920905],
#         [ 4.859935  , -0.67895424, -0.02704749],
#         [ 2.9775078 ,  0.7701418 ,  0.12744647],
#         [ 3.8357663 ,  1.831126  ,  0.22982377],
#         [ 1.5926367 ,  0.9331804 ,  0.15659569],
#         [ 1.1567521 ,  2.2561371 ,  0.3799032 ],
#         [-0.15901338,  2.55709   ,  0.68117636],
#         [-0.47495955,  3.6517425 ,  1.1280073 ],
#         [-1.155264  ,  1.5142894 ,  0.34859166],
#         [-2.506908  ,  1.9020075 ,  0.35500726],
#         [-3.4685857 ,  1.0054184 , -0.06543066],
#         [-4.7789106 ,  1.3804759 , -0.06928323],
#         [-3.1006591 , -0.2541503 , -0.51097035],
#         [-4.0941772 , -1.0813836 , -0.9565406 ],
#         [-1.7605506 , -0.64302415, -0.5096847 ],
#         [-0.7503436 ,  0.21519245, -0.02924622],
# ...

# %%
dataset[2230322]["coordinates"]
# Out:
# [array([[ 0.47853562, -2.7253337 ,  0.07118345],
#         [ 1.2618402 , -1.4393185 ,  0.01563211],
#         [ 2.6700883 , -1.594471  , -0.03544389],
#         [ 3.5100634 , -0.49573776,  0.00920905],
#         [ 4.859935  , -0.67895424, -0.02704749],
#         [ 2.9775078 ,  0.7701418 ,  0.12744647],
#         [ 3.8357663 ,  1.831126  ,  0.22982377],
#         [ 1.5926367 ,  0.9331804 ,  0.15659569],
#         [ 1.1567521 ,  2.2561371 ,  0.3799032 ],
#         [-0.15901338,  2.55709   ,  0.68117636],
#         [-0.47495955,  3.6517425 ,  1.1280073 ],
#         [-1.155264  ,  1.5142894 ,  0.34859166],
#         [-2.506908  ,  1.9020075 ,  0.35500726],
#         [-3.4685857 ,  1.0054184 , -0.06543066],
#         [-4.7789106 ,  1.3804759 , -0.06928323],
#         [-3.1006591 , -0.2541503 , -0.51097035],
#         [-4.0941772 , -1.0813836 , -0.9565406 ],
#         [-1.7605506 , -0.64302415, -0.5096847 ],
#         [-0.7503436 ,  0.21519245, -0.02924622],
# ...
