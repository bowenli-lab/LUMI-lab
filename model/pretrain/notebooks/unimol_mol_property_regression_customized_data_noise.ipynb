# %% [markdown]
# # Uni-Mol Molecular Property Prediction

# %% [markdown]
# **Licenses**
#
# Copyright (c) DP Technology.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.
#
# **Citations**
#
# Please cite the following papers if you use this notebook:
#
# - Gengmo Zhou, Zhifeng Gao, Qiankun Ding, Hang Zheng, Hongteng Xu, Zhewei Wei, Linfeng Zhang, Guolin Ke. "[Uni-Mol: A Universal 3D Molecular Representation Learning Framework.](https://chemrxiv.org/engage/chemrxiv/article-details/6318b529bada388485bc8361)"
# ChemRxiv (2022)

# %% [markdown]
# ## Data Preparation (SMILES, label to .lmdb)

# %%
import os
import lmdb
import pickle
import time
import pandas as pd
import numpy as np
from rdkit import Chem
from tqdm import tqdm
from rdkit.Chem import AllChem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')  
import warnings
warnings.filterwarnings(action='ignore')
from multiprocessing import Pool

# %% [markdown]
# ## Finetuning (based on pretraining)

# %%
date_str = time.strftime("%m%d-%y", time.localtime())

data_path='./'  # replace to your data path
save_dir=f"./save_4CR_{date_str}"  # replace to your save path
MASTER_PORT=10086
n_gpu=1
dict_name='dict.txt'
# weight_path='./weights/mol_pre_no_h_220816.pt'  # replace to your ckpt path, 0.81 when using unimol layers
# weight_path='/fs01/datasets/cellxgene/3d_molecule_save/pretrain-20240502-2040/checkpoint_best.pt'  # on 12 hour training, 0.75 when using unimol layers; 15h 0.77 on a100; 0.72 using pytorch layernorm; 18h 0.80 on a100
weight_path="/home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/mol_pre_no_h_220816.pt"  # on 15 hour training, 0.82 when using unimol layers; 18h 0.84 on a100; 21h 0.82 on a100; 0.84 using pytorch softmax
# weight_path = "/home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/customized_model/checkpoint_best.pt"
# weight_path='/fs01/datasets/cellxgene/3d_molecule_save/pretrain-20240503-2035/checkpoint_best.pt'
# task_name='4CR'  # data folder name
task_name="4CR_customized"
task_num=1
loss_func='finetune_mse_noise'
lr=1e-4
batch_size = local_batch_size=  64 #64
epoch=60
dropout=0.0
warmup=0.06 # 0.06
# local_batch_size=64
only_polar=0 # -1 all h; 0 no h
conf_size=11
seed=0
metric="valid_agg_rmse"
update_freq=batch_size / local_batch_size

# !python -m torch.distributed.launch --nproc_per_node=$n_gpu --master_port=$MASTER_PORT $(which unicore-train) $data_path --task-name $task_name --user-dir ../unimol --train-subset train --valid-subset valid \

# remove the save_dir if exists
if os.path.exists(save_dir):
    os.system(f"rm -rf {save_dir}")

# !cp ../example_data/molecule/$dict_name $data_path
# !export NCCL_ASYNC_ERROR_HANDLING=1
# !export OMP_NUM_THREADS=1
# !python $(which unicore-train) $data_path --task-name $task_name --user-dir ../unimol --train-subset train --valid-subset valid \
       --conf-size $conf_size \
       --num-workers 6 --ddp-backend=c10d \
       --dict-name $dict_name \
       --task mol_finetune --loss $loss_func --arch unimol_base  \
       --classification-head-name $task_name --num-classes $task_num \
       --optimizer adam --adam-betas '(0.9, 0.99)' --adam-eps 1e-6 --clip-norm 1.0 \
       --lr-scheduler polynomial_decay --lr $lr --warmup-ratio $warmup --max-epoch $epoch --batch-size $local_batch_size --pooler-dropout $dropout\
       --update-freq $update_freq --seed $seed \
       --fp16 --fp16-init-scale 4 --fp16-scale-window 256 \
       --log-interval 100 --log-format simple \
       --validate-interval 1 --keep-last-epochs 1 \
       --finetune-from-model $weight_path \
       --best-checkpoint-metric $metric --patience 20 \
       --save-dir $save_dir --only-polar $only_polar \
       # --maximize-best-checkpoint-metric
# --maximize-best-checkpoint-metric, for classification task

# # optional layers
# fused_multi_tensor, probably not really used
# fused_rounding, probably not really used
# fused_layer_norm, tested seems useful
# fused_softmax, tested seems only sometimes useful
# Out:
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | Namespace(no_progress_bar=False, log_interval=100, log_format='simple', tensorboard_logdir='', wandb_project='', wandb_name='', seed=0, cpu=False, fp16=True, bf16=False, bf16_sr=False, allreduce_fp32_grad=False, fp16_no_flatten_grads=False, fp16_init_scale=4, fp16_scale_window=256, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir='../unimol', empty_cache_freq=0, all_gather_list_size=16384, suppress_crashes=False, profile=False, ema_decay=-1.0, validate_with_ema=False, loss='finetune_mse_noise', optimizer='adam', lr_scheduler='polynomial_decay', task='mol_finetune', num_workers=6, skip_invalid_size_inputs_valid_test=False, batch_size=64, required_batch_size_multiple=1, data_buffer_size=10, train_subset='train', valid_subset='valid', validate_interval=1, validate_interval_updates=0, validate_after_updates=0, fixed_validation_seed=None, disable_validation=False, batch_size_valid=64, max_valid_steps=None, curriculum=0, distributed_world_size=1, distributed_rank=0, distributed_backend='nccl', distributed_init_method=None, distributed_port=-1, device_id=0, distributed_no_spawn=False, ddp_backend='c10d', bucket_cap_mb=25, fix_batches_to_gpus=False, find_unused_parameters=False, fast_stat_sync=False, broadcast_buffers=False, nprocs_per_node=1, arch='unimol_base', max_epoch=60, max_update=0, stop_time_hours=0, clip_norm=1.0, per_sample_clip_norm=0, update_freq=[1], lr=[0.0001], stop_min_lr=-1, save_dir='./save_4CR_0508-24', tmp_save_dir='./', restore_file='checkpoint_last.pt', finetune_from_model='/home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/mol_pre_no_h_220816.pt', load_from_ema=False, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, optimizer_overrides='{}', save_interval=1, save_interval_updates=0, keep_interval_updates=-1, keep_last_epochs=1, keep_best_checkpoints=-1, no_save=False, no_epoch_checkpoints=False, no_last_checkpoints=False, no_save_optimizer_state=False, best_checkpoint_metric='valid_agg_rmse', maximize_best_checkpoint_metric=False, patience=20, checkpoint_suffix='', mode='train', data='./', task_name='4CR_customized', classification_head_name='4CR_customized', num_classes=1, no_shuffle=False, conf_size=11, remove_hydrogen=False, remove_polar_hydrogen=False, max_atoms=256, dict_name='dict.txt', only_polar=0, adam_betas='(0.9, 0.99)', adam_eps=1e-06, weight_decay=0.0, force_anneal=None, warmup_updates=0, warmup_ratio=0.06, end_learning_rate=0.0, power=1.0, total_num_update=1000000, pooler_dropout=0.0, no_seed_provided=False, encoder_layers=15, encoder_embed_dim=512, encoder_ffn_embed_dim=2048, encoder_attention_heads=64, dropout=0.1, emb_dropout=0.1, attention_dropout=0.1, activation_dropout=0.0, max_seq_len=512, activation_fn='gelu', pooler_activation_fn='tanh', post_ln=False, masked_token_loss=-1.0, masked_coord_loss=-1.0, masked_dist_loss=-1.0, x_norm_loss=-1.0, delta_pair_repr_norm_loss=-1.0, distributed_num_procs=1)
# 2024-05-08 17:27:45 | INFO | unimol.tasks.unimol_finetune | dictionary: 30 types
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | UniMolModel(
#   (embed_tokens): Embedding(31, 512, padding_idx=0)
#   (encoder): TransformerEncoderWithPair(
#     (emb_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#     (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (7): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (8): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (9): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (10): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (11): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (12): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (13): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#       (14): TransformerEncoderLayer(
#         (self_attn): SelfMultiheadAttention(
#           (in_proj): Linear(in_features=512, out_features=1536, bias=True)
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (final_layer_norm): LayerNorm(torch.Size([512]), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (gbf_proj): NonLinearHead(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=64, bias=True)
#   )
#   (gbf): GaussianLayer(
#     (means): Embedding(1, 128)
#     (stds): Embedding(1, 128)
#     (mul): Embedding(961, 1)
#     (bias): Embedding(961, 1)
#   )
#   (classification_heads): ModuleDict(
#     (4CR_customized): ClassificationHead(
#       (dense): Linear(in_features=512, out_features=512, bias=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#       (out_proj): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
# )
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | task: UniMolFinetuneTask
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | model: UniMolModel
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | loss: FinetuneMSE_NOISE_Loss
# 2024-05-08 17:27:45 | INFO | unicore_cli.train | num. model params: 47,593,795 (num. trained: 47,593,795)
# 2024-05-08 17:27:46 | INFO | unicore.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-05-08 17:27:46 | INFO | unicore.utils | rank   0: capabilities =  8.6  ; total memory = 23.671 GB ; name = NVIDIA GeForce RTX 3090 Ti
# 2024-05-08 17:27:46 | INFO | unicore.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-05-08 17:27:46 | INFO | unicore_cli.train | training on 1 devices (GPUs)
# 2024-05-08 17:27:46 | INFO | unicore_cli.train | batch size per device = 64
# 2024-05-08 17:27:46 | INFO | unicore.checkpoint_utils | loading pretrained model from /home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/mol_pre_no_h_220816.pt: optimizer, lr scheduler, meters, dataloader will be reset
# 2024-05-08 17:27:46 | INFO | unicore.trainer | Preparing to load checkpoint /home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/mol_pre_no_h_220816.pt
# 2024-05-08 17:27:46 | WARNING | unicore.trainer | Error in loading model state, missing_keys ['classification_heads.4CR_customized.dense.weight', 'classification_heads.4CR_customized.dense.bias', 'classification_heads.4CR_customized.out_proj.weight', 'classification_heads.4CR_customized.out_proj.bias']
# 2024-05-08 17:27:46 | WARNING | unicore.trainer | Error in loading model state, unexpected_keys ['lm_head.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'pair2coord_proj.linear1.weight', 'pair2coord_proj.linear1.bias', 'pair2coord_proj.linear2.weight', 'pair2coord_proj.linear2.bias', 'dist_head.dense.weight', 'dist_head.dense.bias', 'dist_head.layer_norm.weight', 'dist_head.layer_norm.bias', 'dist_head.out_proj.weight', 'dist_head.out_proj.bias', 'encoder.final_head_layer_norm.weight', 'encoder.final_head_layer_norm.bias']
# 2024-05-08 17:27:46 | INFO | unicore.trainer | Loaded checkpoint /home/pangkuan/dev/SDL-LNP/model/evaluation/notebooks/model_weight/mol_pre_no_h_220816.pt
# 2024-05-08 17:27:46 | INFO | unicore.trainer | loading train data for epoch 1
# 2024-05-08 17:27:46 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:27:46 | INFO | unicore.optim.adam | using FusedAdam
# 2024-05-08 17:27:46 | INFO | unicore.trainer | begin training epoch 1
# 2024-05-08 17:27:46 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:27:47 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 2.0
# 2024-05-08 17:27:47 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 1.0
# 2024-05-08 17:27:48 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:27:48 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:27:49 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 20.551 | valid_mae 3.148 | valid_mse 13.934 | valid_agg_mae 3.148 | valid_agg_mse 13.933 | valid_agg_rmse 3.7326 | bsz 2112 | num_updates 22
# 2024-05-08 17:27:49 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 22 updates
# 2024-05-08 17:27:49 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint1.pt
# 2024-05-08 17:27:50 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint1.pt
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint1.pt (epoch 1 @ 22 updates, score 3.7326) (writing took 0.4668793570017442 seconds)
# 2024-05-08 17:27:50 | INFO | unicore_cli.train | end of epoch 1 (average epoch stats below)
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | copy ./checkpoint1.pt to ./save_4CR_0508-24/checkpoint1.pt
# 2024-05-08 17:27:50 | INFO | train | epoch 001 | loss 35.573 | ups 7.74 | bsz 64 | num_updates 22 | lr 2.44444e-05 | gnorm 315.685 | clip 100 | loss_scale 1 | train_wall 2.24 | gb_free 19.3 | wall 4
# 2024-05-08 17:27:50 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 2
# 2024-05-08 17:27:50 | INFO | unicore.trainer | begin training epoch 2
# 2024-05-08 17:27:50 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | copy ./checkpoint1.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | copy ./checkpoint1.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint1.pt ...
# 2024-05-08 17:27:50 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:27:51 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:27:51 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:27:52 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 20.99 | valid_mae 3.199 | valid_mse 14.379 | valid_agg_mae 3.199 | valid_agg_mse 14.378 | valid_agg_rmse 3.7918 | bsz 2112 | num_updates 46 | best_valid_agg_rmse 3.7326
# 2024-05-08 17:27:52 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 46 updates
# 2024-05-08 17:27:52 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint2.pt
# 2024-05-08 17:27:53 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint2.pt
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint2.pt (epoch 2 @ 46 updates, score 3.7918) (writing took 0.46912537299795076 seconds)
# 2024-05-08 17:27:53 | INFO | unicore_cli.train | end of epoch 2 (average epoch stats below)
# 2024-05-08 17:27:53 | INFO | train | epoch 002 | loss 23.539 | ups 8.04 | bsz 64 | num_updates 46 | lr 5.11111e-05 | gnorm 267.415 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 7
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | copy ./checkpoint2.pt to ./save_4CR_0508-24/checkpoint2.pt
# 2024-05-08 17:27:53 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 3
# 2024-05-08 17:27:53 | INFO | unicore.trainer | begin training epoch 3
# 2024-05-08 17:27:53 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | copy ./checkpoint2.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint2.pt ...
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint1.pt
# 2024-05-08 17:27:53 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:27:53 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 0.5
# 2024-05-08 17:27:54 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 0.25
# 2024-05-08 17:27:54 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:27:54 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:27:55 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 17.99 | valid_mae 2.952 | valid_mse 12.317 | valid_agg_mae 2.944 | valid_agg_mse 12.23 | valid_agg_rmse 3.4971 | bsz 2112 | num_updates 68 | best_valid_agg_rmse 3.4971
# 2024-05-08 17:27:55 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 68 updates
# 2024-05-08 17:27:55 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint3.pt
# 2024-05-08 17:27:56 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint3.pt
# 2024-05-08 17:27:56 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint3.pt (epoch 3 @ 68 updates, score 3.4971) (writing took 0.46943760200520046 seconds)
# 2024-05-08 17:27:56 | INFO | unicore_cli.train | end of epoch 3 (average epoch stats below)
# 2024-05-08 17:27:56 | INFO | unicore.checkpoint_utils | copy ./checkpoint3.pt to ./save_4CR_0508-24/checkpoint3.pt
# 2024-05-08 17:27:56 | INFO | train | epoch 003 | loss 22.005 | ups 7.32 | bsz 64 | num_updates 68 | lr 7.55556e-05 | gnorm 551.376 | clip 100 | loss_scale 0.25 | train_wall 1.53 | gb_free 19.3 | wall 10
# 2024-05-08 17:27:56 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 4
# 2024-05-08 17:27:56 | INFO | unicore.trainer | begin training epoch 4
# 2024-05-08 17:27:56 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:27:56 | INFO | unicore.checkpoint_utils | copy ./checkpoint3.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:27:56 | INFO | unicore.checkpoint_utils | copy ./checkpoint3.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:27:57 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint3.pt ...
# 2024-05-08 17:27:57 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint2.pt
# 2024-05-08 17:27:57 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:27:57 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:27:57 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:27:58 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 13.621 | valid_mae 2.425 | valid_mse 9.192 | valid_agg_mae 2.304 | valid_agg_mse 8.264 | valid_agg_rmse 2.8746 | bsz 2112 | num_updates 92 | best_valid_agg_rmse 2.8746
# 2024-05-08 17:27:58 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 92 updates
# 2024-05-08 17:27:58 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint4.pt
# 2024-05-08 17:27:59 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint4.pt
# 2024-05-08 17:27:59 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint4.pt (epoch 4 @ 92 updates, score 2.8746) (writing took 0.4672671149892267 seconds)
# 2024-05-08 17:27:59 | INFO | unicore_cli.train | end of epoch 4 (average epoch stats below)
# 2024-05-08 17:27:59 | INFO | unicore.checkpoint_utils | copy ./checkpoint4.pt to ./save_4CR_0508-24/checkpoint4.pt
# 2024-05-08 17:27:59 | INFO | train | epoch 004 | loss 17.7 | ups 8.01 | bsz 64 | num_updates 92 | lr 9.98582e-05 | gnorm 2151.28 | clip 100 | loss_scale 0.25 | train_wall 1.54 | gb_free 19.3 | wall 13
# 2024-05-08 17:27:59 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 5
# 2024-05-08 17:27:59 | INFO | unicore.trainer | begin training epoch 5
# 2024-05-08 17:27:59 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:27:59 | INFO | unicore.checkpoint_utils | copy ./checkpoint4.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:27:59 | INFO | unicore.checkpoint_utils | copy ./checkpoint4.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:27:59 | INFO | train_inner | epoch 005:      8 / 24 loss=23.829, ups=7.96, bsz=64, num_updates=100, lr=9.92908e-05, gnorm=939.969, clip=100, loss_scale=0.25, train_wall=7.37, gb_free=19.3, wall=14
# 2024-05-08 17:27:59 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint4.pt ...
# 2024-05-08 17:28:00 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint3.pt
# 2024-05-08 17:28:00 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:00 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:00 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:01 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 13.211 | valid_mae 2.411 | valid_mse 8.902 | valid_agg_mae 2.366 | valid_agg_mse 8.487 | valid_agg_rmse 2.9133 | bsz 2112 | num_updates 116 | best_valid_agg_rmse 2.8746
# 2024-05-08 17:28:01 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 5 @ 116 updates
# 2024-05-08 17:28:01 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint5.pt
# 2024-05-08 17:28:02 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint5.pt
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint5.pt (epoch 5 @ 116 updates, score 2.9133) (writing took 0.47389458800898865 seconds)
# 2024-05-08 17:28:02 | INFO | unicore_cli.train | end of epoch 5 (average epoch stats below)
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | copy ./checkpoint5.pt to ./save_4CR_0508-24/checkpoint5.pt
# 2024-05-08 17:28:02 | INFO | train | epoch 005 | loss 15.383 | ups 8 | bsz 64 | num_updates 116 | lr 9.8156e-05 | gnorm 1626.23 | clip 100 | loss_scale 0.25 | train_wall 1.54 | gb_free 19.3 | wall 16
# 2024-05-08 17:28:02 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 6
# 2024-05-08 17:28:02 | INFO | unicore.trainer | begin training epoch 6
# 2024-05-08 17:28:02 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | copy ./checkpoint5.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint5.pt ...
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint4.pt
# 2024-05-08 17:28:02 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:03 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:03 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:04 | INFO | valid | epoch 006 | valid on 'valid' subset | loss 11.219 | valid_mae 2.124 | valid_mse 7.573 | valid_agg_mae 2.088 | valid_agg_mse 7.281 | valid_agg_rmse 2.6983 | bsz 2112 | num_updates 140 | best_valid_agg_rmse 2.6983
# 2024-05-08 17:28:04 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 6 @ 140 updates
# 2024-05-08 17:28:04 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint6.pt
# 2024-05-08 17:28:05 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint6.pt
# 2024-05-08 17:28:05 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint6.pt (epoch 6 @ 140 updates, score 2.6983) (writing took 0.4645059499889612 seconds)
# 2024-05-08 17:28:05 | INFO | unicore_cli.train | end of epoch 6 (average epoch stats below)
# 2024-05-08 17:28:05 | INFO | unicore.checkpoint_utils | copy ./checkpoint6.pt to ./save_4CR_0508-24/checkpoint6.pt
# 2024-05-08 17:28:05 | INFO | train | epoch 006 | loss 13.11 | ups 8.09 | bsz 64 | num_updates 140 | lr 9.64539e-05 | gnorm 1076.46 | clip 100 | loss_scale 0.25 | train_wall 1.54 | gb_free 19.3 | wall 19
# 2024-05-08 17:28:05 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 7
# 2024-05-08 17:28:05 | INFO | unicore.trainer | begin training epoch 7
# 2024-05-08 17:28:05 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:05 | INFO | unicore.checkpoint_utils | copy ./checkpoint6.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:28:05 | INFO | unicore.checkpoint_utils | copy ./checkpoint6.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:05 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint6.pt ...
# 2024-05-08 17:28:06 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint5.pt
# 2024-05-08 17:28:06 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:06 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:06 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:07 | INFO | valid | epoch 007 | valid on 'valid' subset | loss 11.394 | valid_mae 2.229 | valid_mse 7.705 | valid_agg_mae 2.178 | valid_agg_mse 7.215 | valid_agg_rmse 2.6861 | bsz 2112 | num_updates 164 | best_valid_agg_rmse 2.6861
# 2024-05-08 17:28:07 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 7 @ 164 updates
# 2024-05-08 17:28:07 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint7.pt
# 2024-05-08 17:28:08 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint7.pt
# 2024-05-08 17:28:08 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint7.pt (epoch 7 @ 164 updates, score 2.6861) (writing took 0.47219872497953475 seconds)
# 2024-05-08 17:28:08 | INFO | unicore_cli.train | end of epoch 7 (average epoch stats below)
# 2024-05-08 17:28:08 | INFO | train | epoch 007 | loss 14.028 | ups 7.98 | bsz 64 | num_updates 164 | lr 9.47518e-05 | gnorm 1482.94 | clip 100 | loss_scale 0.25 | train_wall 1.54 | gb_free 19.3 | wall 22
# 2024-05-08 17:28:08 | INFO | unicore.checkpoint_utils | copy ./checkpoint7.pt to ./save_4CR_0508-24/checkpoint7.pt
# 2024-05-08 17:28:08 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 8
# 2024-05-08 17:28:08 | INFO | unicore.trainer | begin training epoch 8
# 2024-05-08 17:28:08 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:08 | INFO | unicore.checkpoint_utils | copy ./checkpoint7.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:28:08 | INFO | unicore.checkpoint_utils | copy ./checkpoint7.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:09 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint7.pt ...
# 2024-05-08 17:28:09 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint6.pt
# 2024-05-08 17:28:09 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:09 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:09 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:10 | INFO | valid | epoch 008 | valid on 'valid' subset | loss 10.848 | valid_mae 2.056 | valid_mse 7.155 | valid_agg_mae 1.997 | valid_agg_mse 6.679 | valid_agg_rmse 2.5845 | bsz 2112 | num_updates 188 | best_valid_agg_rmse 2.5845
# 2024-05-08 17:28:10 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 8 @ 188 updates
# 2024-05-08 17:28:10 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint8.pt
# 2024-05-08 17:28:11 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint8.pt
# 2024-05-08 17:28:11 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint8.pt (epoch 8 @ 188 updates, score 2.5845) (writing took 0.4649557610100601 seconds)
# 2024-05-08 17:28:11 | INFO | unicore_cli.train | end of epoch 8 (average epoch stats below)
# 2024-05-08 17:28:11 | INFO | unicore.checkpoint_utils | copy ./checkpoint8.pt to ./save_4CR_0508-24/checkpoint8.pt
# 2024-05-08 17:28:11 | INFO | train | epoch 008 | loss 11.595 | ups 8.02 | bsz 64 | num_updates 188 | lr 9.30496e-05 | gnorm 1019.84 | clip 100 | loss_scale 0.25 | train_wall 1.54 | gb_free 19.3 | wall 25
# 2024-05-08 17:28:11 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 9
# 2024-05-08 17:28:11 | INFO | unicore.trainer | begin training epoch 9
# 2024-05-08 17:28:11 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:11 | INFO | unicore.checkpoint_utils | copy ./checkpoint8.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:28:11 | INFO | unicore.checkpoint_utils | copy ./checkpoint8.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:12 | INFO | train_inner | epoch 009:     12 / 24 loss=12.974, ups=8.17, bsz=64, num_updates=200, lr=9.21986e-05, gnorm=1188.58, clip=100, loss_scale=0.25, train_wall=6.41, gb_free=19.3, wall=26
# 2024-05-08 17:28:12 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint8.pt ...
# 2024-05-08 17:28:12 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint7.pt
# 2024-05-08 17:28:12 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:12 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 0.125
# 2024-05-08 17:28:12 | INFO | unicore.trainer | NOTE: gradient overflow detected, ignoring gradient, setting loss scale to: 0.0625
# 2024-05-08 17:28:12 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:12 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:13 | INFO | valid | epoch 009 | valid on 'valid' subset | loss 13.769 | valid_mae 2.344 | valid_mse 9.307 | valid_agg_mae 2.304 | valid_agg_mse 9.006 | valid_agg_rmse 3.0011 | bsz 2112 | num_updates 210 | best_valid_agg_rmse 2.5845
# 2024-05-08 17:28:13 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 9 @ 210 updates
# 2024-05-08 17:28:13 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint9.pt
# 2024-05-08 17:28:14 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint9.pt
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint9.pt (epoch 9 @ 210 updates, score 3.0011) (writing took 0.4719981259841006 seconds)
# 2024-05-08 17:28:14 | INFO | unicore_cli.train | end of epoch 9 (average epoch stats below)
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | copy ./checkpoint9.pt to ./save_4CR_0508-24/checkpoint9.pt
# 2024-05-08 17:28:14 | INFO | train | epoch 009 | loss 12.043 | ups 7.36 | bsz 64 | num_updates 210 | lr 9.14894e-05 | gnorm 2555.35 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 28
# 2024-05-08 17:28:14 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 10
# 2024-05-08 17:28:14 | INFO | unicore.trainer | begin training epoch 10
# 2024-05-08 17:28:14 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | copy ./checkpoint9.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint9.pt ...
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint8.pt
# 2024-05-08 17:28:14 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:15 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:15 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:16 | INFO | valid | epoch 010 | valid on 'valid' subset | loss 10.179 | valid_mae 1.992 | valid_mse 6.827 | valid_agg_mae 1.943 | valid_agg_mse 6.422 | valid_agg_rmse 2.5343 | bsz 2112 | num_updates 234 | best_valid_agg_rmse 2.5343
# 2024-05-08 17:28:16 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 10 @ 234 updates
# 2024-05-08 17:28:16 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint10.pt
# 2024-05-08 17:28:17 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint10.pt
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint10.pt (epoch 10 @ 234 updates, score 2.5343) (writing took 0.471277253003791 seconds)
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | copy ./checkpoint10.pt to ./save_4CR_0508-24/checkpoint10.pt
# 2024-05-08 17:28:17 | INFO | unicore_cli.train | end of epoch 10 (average epoch stats below)
# 2024-05-08 17:28:17 | INFO | train | epoch 010 | loss 10.401 | ups 7.98 | bsz 64 | num_updates 234 | lr 8.97872e-05 | gnorm 1282.27 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 31
# 2024-05-08 17:28:17 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 11
# 2024-05-08 17:28:17 | INFO | unicore.trainer | begin training epoch 11
# 2024-05-08 17:28:17 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | copy ./checkpoint10.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | copy ./checkpoint10.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint10.pt ...
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint9.pt
# 2024-05-08 17:28:17 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:18 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:18 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:19 | INFO | valid | epoch 011 | valid on 'valid' subset | loss 10.584 | valid_mae 2.023 | valid_mse 7.088 | valid_agg_mae 1.988 | valid_agg_mse 6.803 | valid_agg_rmse 2.6082 | bsz 2112 | num_updates 258 | best_valid_agg_rmse 2.5343
# 2024-05-08 17:28:19 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 11 @ 258 updates
# 2024-05-08 17:28:19 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint11.pt
# 2024-05-08 17:28:20 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint11.pt
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint11.pt (epoch 11 @ 258 updates, score 2.6082) (writing took 0.4711897879897151 seconds)
# 2024-05-08 17:28:20 | INFO | unicore_cli.train | end of epoch 11 (average epoch stats below)
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | copy ./checkpoint11.pt to ./save_4CR_0508-24/checkpoint11.pt
# 2024-05-08 17:28:20 | INFO | train | epoch 011 | loss 9.313 | ups 8 | bsz 64 | num_updates 258 | lr 8.80851e-05 | gnorm 991.261 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 34
# 2024-05-08 17:28:20 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 12
# 2024-05-08 17:28:20 | INFO | unicore.trainer | begin training epoch 12
# 2024-05-08 17:28:20 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | copy ./checkpoint11.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint11.pt ...
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint10.pt
# 2024-05-08 17:28:20 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:21 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:21 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:22 | INFO | valid | epoch 012 | valid on 'valid' subset | loss 10.674 | valid_mae 2.08 | valid_mse 7.062 | valid_agg_mae 2.04 | valid_agg_mse 6.748 | valid_agg_rmse 2.5977 | bsz 2112 | num_updates 282 | best_valid_agg_rmse 2.5343
# 2024-05-08 17:28:22 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 12 @ 282 updates
# 2024-05-08 17:28:22 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint12.pt
# 2024-05-08 17:28:23 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint12.pt
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint12.pt (epoch 12 @ 282 updates, score 2.5977) (writing took 0.47091369301779196 seconds)
# 2024-05-08 17:28:23 | INFO | unicore_cli.train | end of epoch 12 (average epoch stats below)
# 2024-05-08 17:28:23 | INFO | train | epoch 012 | loss 9.619 | ups 7.99 | bsz 64 | num_updates 282 | lr 8.6383e-05 | gnorm 908.61 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 37
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | copy ./checkpoint12.pt to ./save_4CR_0508-24/checkpoint12.pt
# 2024-05-08 17:28:23 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 13
# 2024-05-08 17:28:23 | INFO | unicore.trainer | begin training epoch 13
# 2024-05-08 17:28:23 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | copy ./checkpoint12.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint12.pt ...
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint11.pt
# 2024-05-08 17:28:23 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:24 | INFO | train_inner | epoch 013:     18 / 24 loss=10.242, ups=8.08, bsz=64, num_updates=300, lr=8.51064e-05, gnorm=1384.13, clip=100, loss_scale=0.0625, train_wall=6.51, gb_free=19.3, wall=38
# 2024-05-08 17:28:24 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:24 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:25 | INFO | valid | epoch 013 | valid on 'valid' subset | loss 10.449 | valid_mae 2.049 | valid_mse 7.056 | valid_agg_mae 2.002 | valid_agg_mse 6.719 | valid_agg_rmse 2.592 | bsz 2112 | num_updates 306 | best_valid_agg_rmse 2.5343
# 2024-05-08 17:28:25 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 13 @ 306 updates
# 2024-05-08 17:28:25 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint13.pt
# 2024-05-08 17:28:26 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint13.pt
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint13.pt (epoch 13 @ 306 updates, score 2.592) (writing took 0.4725652680208441 seconds)
# 2024-05-08 17:28:26 | INFO | unicore_cli.train | end of epoch 13 (average epoch stats below)
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | copy ./checkpoint13.pt to ./save_4CR_0508-24/checkpoint13.pt
# 2024-05-08 17:28:26 | INFO | train | epoch 013 | loss 9.689 | ups 8.03 | bsz 64 | num_updates 306 | lr 8.46809e-05 | gnorm 862.138 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 40
# 2024-05-08 17:28:26 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 14
# 2024-05-08 17:28:26 | INFO | unicore.trainer | begin training epoch 14
# 2024-05-08 17:28:26 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | copy ./checkpoint13.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint13.pt ...
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint12.pt
# 2024-05-08 17:28:26 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:27 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:27 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:28 | INFO | valid | epoch 014 | valid on 'valid' subset | loss 10.587 | valid_mae 2.055 | valid_mse 6.998 | valid_agg_mae 2.024 | valid_agg_mse 6.736 | valid_agg_rmse 2.5954 | bsz 2112 | num_updates 330 | best_valid_agg_rmse 2.5343
# 2024-05-08 17:28:28 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 14 @ 330 updates
# 2024-05-08 17:28:28 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint14.pt
# 2024-05-08 17:28:29 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint14.pt
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint14.pt (epoch 14 @ 330 updates, score 2.5954) (writing took 0.4652083140099421 seconds)
# 2024-05-08 17:28:29 | INFO | unicore_cli.train | end of epoch 14 (average epoch stats below)
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | copy ./checkpoint14.pt to ./save_4CR_0508-24/checkpoint14.pt
# 2024-05-08 17:28:29 | INFO | train | epoch 014 | loss 8.676 | ups 8.03 | bsz 64 | num_updates 330 | lr 8.29787e-05 | gnorm 629.841 | clip 100 | loss_scale 0.0625 | train_wall 1.54 | gb_free 19.3 | wall 43
# 2024-05-08 17:28:29 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 15
# 2024-05-08 17:28:29 | INFO | unicore.trainer | begin training epoch 15
# 2024-05-08 17:28:29 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | copy ./checkpoint14.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint14.pt ...
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint13.pt
# 2024-05-08 17:28:29 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:30 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:30 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:31 | INFO | valid | epoch 015 | valid on 'valid' subset | loss 9.534 | valid_mae 1.899 | valid_mse 6.34 | valid_agg_mae 1.867 | valid_agg_mse 6.059 | valid_agg_rmse 2.4616 | bsz 2112 | num_updates 354 | best_valid_agg_rmse 2.4616
# 2024-05-08 17:28:31 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 15 @ 354 updates
# 2024-05-08 17:28:31 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint15.pt
# 2024-05-08 17:28:32 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint15.pt
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint15.pt (epoch 15 @ 354 updates, score 2.4616) (writing took 0.4723577050026506 seconds)
# 2024-05-08 17:28:32 | INFO | unicore_cli.train | end of epoch 15 (average epoch stats below)
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | copy ./checkpoint15.pt to ./save_4CR_0508-24/checkpoint15.pt
# 2024-05-08 17:28:32 | INFO | train | epoch 015 | loss 8.759 | ups 8 | bsz 64 | num_updates 354 | lr 8.12766e-05 | gnorm 600.039 | clip 100 | loss_scale 0.0625 | train_wall 1.53 | gb_free 19.3 | wall 46
# 2024-05-08 17:28:32 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 16
# 2024-05-08 17:28:32 | INFO | unicore.trainer | begin training epoch 16
# 2024-05-08 17:28:32 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | copy ./checkpoint15.pt to ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | copy ./checkpoint15.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint15.pt ...
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint14.pt
# 2024-05-08 17:28:32 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:28:33 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:28:33 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:28:34 | INFO | valid | epoch 016 | valid on 'valid' subset | loss 9.989 | valid_mae 1.979 | valid_mse 6.599 | valid_agg_mae 1.939 | valid_agg_mse 6.203 | valid_agg_rmse 2.4906 | bsz 2112 | num_updates 378 | best_valid_agg_rmse 2.4616
# 2024-05-08 17:28:34 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 16 @ 378 updates
# 2024-05-08 17:28:34 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint16.pt
# 2024-05-08 17:28:35 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint16.pt
# 2024-05-08 17:28:35 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint16.pt (epoch 16 @ 378 updates, score 2.4906) (writing took 0.47009060697746463 seconds)
# 2024-05-08 17:28:35 | INFO | unicore_cli.train | end of epoch 16 (average epoch stats below)
# 2024-05-08 17:28:35 | INFO | train | epoch 016 | loss 8.548 | ups 8.01 | bsz 64 | num_updates 378 | lr 7.95745e-05 | gnorm 611.769 | clip 100 | loss_scale 0.0625 | train_wall 1.54 | gb_free 19.3 | wall 49
# ...
# 2024-05-08 17:30:17 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint49.pt
# 2024-05-08 17:30:17 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:18 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:18 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:19 | INFO | valid | epoch 051 | valid on 'valid' subset | loss 8.69 | valid_mae 1.882 | valid_mse 5.751 | valid_agg_mae 1.802 | valid_agg_mse 5.143 | valid_agg_rmse 2.2677 | bsz 2112 | num_updates 1218 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:19 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 51 @ 1218 updates
# 2024-05-08 17:30:19 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint51.pt
# 2024-05-08 17:30:19 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint51.pt
# 2024-05-08 17:30:19 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint51.pt (epoch 51 @ 1218 updates, score 2.2677) (writing took 0.4724502669996582 seconds)
# 2024-05-08 17:30:19 | INFO | unicore_cli.train | end of epoch 51 (average epoch stats below)
# 2024-05-08 17:30:19 | INFO | unicore.checkpoint_utils | copy ./checkpoint51.pt to ./save_4CR_0508-24/checkpoint51.pt
# 2024-05-08 17:30:19 | INFO | train | epoch 051 | loss 3.392 | ups 8.04 | bsz 64 | num_updates 1218 | lr 2e-05 | gnorm 321.051 | clip 100 | loss_scale 0.5 | train_wall 1.53 | gb_free 19.3 | wall 153
# 2024-05-08 17:30:19 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 52
# 2024-05-08 17:30:19 | INFO | unicore.trainer | begin training epoch 52
# 2024-05-08 17:30:19 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:20 | INFO | unicore.checkpoint_utils | copy ./checkpoint51.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:20 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint51.pt ...
# 2024-05-08 17:30:20 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint50.pt
# 2024-05-08 17:30:20 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:21 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:21 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:22 | INFO | valid | epoch 052 | valid on 'valid' subset | loss 7.933 | valid_mae 1.836 | valid_mse 5.257 | valid_agg_mae 1.755 | valid_agg_mse 4.611 | valid_agg_rmse 2.1473 | bsz 2112 | num_updates 1242 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:22 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 52 @ 1242 updates
# 2024-05-08 17:30:22 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint52.pt
# 2024-05-08 17:30:22 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint52.pt
# 2024-05-08 17:30:22 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint52.pt (epoch 52 @ 1242 updates, score 2.1473) (writing took 0.4704835139855277 seconds)
# 2024-05-08 17:30:22 | INFO | unicore_cli.train | end of epoch 52 (average epoch stats below)
# 2024-05-08 17:30:22 | INFO | unicore.checkpoint_utils | copy ./checkpoint52.pt to ./save_4CR_0508-24/checkpoint52.pt
# 2024-05-08 17:30:22 | INFO | train | epoch 052 | loss 3.379 | ups 8.05 | bsz 64 | num_updates 1242 | lr 1.82979e-05 | gnorm 299.328 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 156
# 2024-05-08 17:30:22 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 53
# 2024-05-08 17:30:22 | INFO | unicore.trainer | begin training epoch 53
# 2024-05-08 17:30:22 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:22 | INFO | unicore.checkpoint_utils | copy ./checkpoint52.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:23 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint52.pt ...
# 2024-05-08 17:30:23 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint51.pt
# 2024-05-08 17:30:23 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:24 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:24 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:25 | INFO | valid | epoch 053 | valid on 'valid' subset | loss 8.292 | valid_mae 1.853 | valid_mse 5.524 | valid_agg_mae 1.771 | valid_agg_mse 4.869 | valid_agg_rmse 2.2065 | bsz 2112 | num_updates 1266 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:25 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 53 @ 1266 updates
# 2024-05-08 17:30:25 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint53.pt
# 2024-05-08 17:30:25 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint53.pt
# 2024-05-08 17:30:25 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint53.pt (epoch 53 @ 1266 updates, score 2.2065) (writing took 0.47361388700664975 seconds)
# 2024-05-08 17:30:25 | INFO | unicore_cli.train | end of epoch 53 (average epoch stats below)
# 2024-05-08 17:30:25 | INFO | unicore.checkpoint_utils | copy ./checkpoint53.pt to ./save_4CR_0508-24/checkpoint53.pt
# 2024-05-08 17:30:25 | INFO | train | epoch 053 | loss 3.224 | ups 8.06 | bsz 64 | num_updates 1266 | lr 1.65957e-05 | gnorm 280.592 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 159
# 2024-05-08 17:30:25 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 54
# 2024-05-08 17:30:25 | INFO | unicore.trainer | begin training epoch 54
# 2024-05-08 17:30:25 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:25 | INFO | unicore.checkpoint_utils | copy ./checkpoint53.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:26 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint53.pt ...
# 2024-05-08 17:30:26 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint52.pt
# 2024-05-08 17:30:26 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:27 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:27 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:28 | INFO | valid | epoch 054 | valid on 'valid' subset | loss 7.979 | valid_mae 1.842 | valid_mse 5.285 | valid_agg_mae 1.751 | valid_agg_mse 4.674 | valid_agg_rmse 2.1619 | bsz 2112 | num_updates 1290 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:28 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 54 @ 1290 updates
# 2024-05-08 17:30:28 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint54.pt
# 2024-05-08 17:30:28 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint54.pt
# 2024-05-08 17:30:28 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint54.pt (epoch 54 @ 1290 updates, score 2.1619) (writing took 0.47234200400998816 seconds)
# 2024-05-08 17:30:28 | INFO | unicore_cli.train | end of epoch 54 (average epoch stats below)
# 2024-05-08 17:30:28 | INFO | unicore.checkpoint_utils | copy ./checkpoint54.pt to ./save_4CR_0508-24/checkpoint54.pt
# 2024-05-08 17:30:28 | INFO | train | epoch 054 | loss 3.346 | ups 8.05 | bsz 64 | num_updates 1290 | lr 1.48936e-05 | gnorm 312.929 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 162
# 2024-05-08 17:30:28 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 55
# 2024-05-08 17:30:28 | INFO | unicore.trainer | begin training epoch 55
# 2024-05-08 17:30:28 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:28 | INFO | unicore.checkpoint_utils | copy ./checkpoint54.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:29 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint54.pt ...
# 2024-05-08 17:30:29 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint53.pt
# 2024-05-08 17:30:29 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:29 | INFO | train_inner | epoch 055:     10 / 24 loss=3.316, ups=8.2, bsz=64, num_updates=1300, lr=1.41844e-05, gnorm=296.853, clip=100, loss_scale=1, train_wall=6.39, gb_free=19.3, wall=163
# 2024-05-08 17:30:30 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:30 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:31 | INFO | valid | epoch 055 | valid on 'valid' subset | loss 8.638 | valid_mae 1.909 | valid_mse 5.745 | valid_agg_mae 1.823 | valid_agg_mse 5.113 | valid_agg_rmse 2.2612 | bsz 2112 | num_updates 1314 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:31 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 55 @ 1314 updates
# 2024-05-08 17:30:31 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint55.pt
# 2024-05-08 17:30:31 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint55.pt
# 2024-05-08 17:30:31 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint55.pt (epoch 55 @ 1314 updates, score 2.2612) (writing took 0.4813397090183571 seconds)
# 2024-05-08 17:30:31 | INFO | unicore_cli.train | end of epoch 55 (average epoch stats below)
# 2024-05-08 17:30:31 | INFO | unicore.checkpoint_utils | copy ./checkpoint55.pt to ./save_4CR_0508-24/checkpoint55.pt
# 2024-05-08 17:30:31 | INFO | train | epoch 055 | loss 3.236 | ups 7.98 | bsz 64 | num_updates 1314 | lr 1.31915e-05 | gnorm 351.682 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 165
# 2024-05-08 17:30:31 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 56
# 2024-05-08 17:30:31 | INFO | unicore.trainer | begin training epoch 56
# 2024-05-08 17:30:31 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:31 | INFO | unicore.checkpoint_utils | copy ./checkpoint55.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:32 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint55.pt ...
# 2024-05-08 17:30:32 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint54.pt
# 2024-05-08 17:30:32 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:33 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:33 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:34 | INFO | valid | epoch 056 | valid on 'valid' subset | loss 9.241 | valid_mae 1.959 | valid_mse 6.153 | valid_agg_mae 1.866 | valid_agg_mse 5.482 | valid_agg_rmse 2.3414 | bsz 2112 | num_updates 1338 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:34 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 56 @ 1338 updates
# 2024-05-08 17:30:34 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint56.pt
# 2024-05-08 17:30:34 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint56.pt
# 2024-05-08 17:30:34 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint56.pt (epoch 56 @ 1338 updates, score 2.3414) (writing took 0.4718369089823682 seconds)
# 2024-05-08 17:30:34 | INFO | unicore_cli.train | end of epoch 56 (average epoch stats below)
# 2024-05-08 17:30:34 | INFO | unicore.checkpoint_utils | copy ./checkpoint56.pt to ./save_4CR_0508-24/checkpoint56.pt
# 2024-05-08 17:30:34 | INFO | train | epoch 056 | loss 3.232 | ups 7.99 | bsz 64 | num_updates 1338 | lr 1.14894e-05 | gnorm 315.304 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 168
# 2024-05-08 17:30:34 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 57
# 2024-05-08 17:30:34 | INFO | unicore.trainer | begin training epoch 57
# 2024-05-08 17:30:34 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:34 | INFO | unicore.checkpoint_utils | copy ./checkpoint56.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:35 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint56.pt ...
# 2024-05-08 17:30:35 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint55.pt
# 2024-05-08 17:30:35 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:36 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:36 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:37 | INFO | valid | epoch 057 | valid on 'valid' subset | loss 8.242 | valid_mae 1.849 | valid_mse 5.456 | valid_agg_mae 1.769 | valid_agg_mse 4.838 | valid_agg_rmse 2.1996 | bsz 2112 | num_updates 1362 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:37 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 57 @ 1362 updates
# 2024-05-08 17:30:37 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint57.pt
# 2024-05-08 17:30:37 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint57.pt
# 2024-05-08 17:30:37 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint57.pt (epoch 57 @ 1362 updates, score 2.1996) (writing took 0.4750959490193054 seconds)
# 2024-05-08 17:30:37 | INFO | unicore_cli.train | end of epoch 57 (average epoch stats below)
# 2024-05-08 17:30:37 | INFO | unicore.checkpoint_utils | copy ./checkpoint57.pt to ./save_4CR_0508-24/checkpoint57.pt
# 2024-05-08 17:30:37 | INFO | train | epoch 057 | loss 3.023 | ups 7.98 | bsz 64 | num_updates 1362 | lr 9.78723e-06 | gnorm 271.282 | clip 100 | loss_scale 1 | train_wall 1.53 | gb_free 19.3 | wall 171
# 2024-05-08 17:30:37 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 58
# 2024-05-08 17:30:37 | INFO | unicore.trainer | begin training epoch 58
# 2024-05-08 17:30:37 | INFO | unicore_cli.train | Start iterating over samples
# 2024-05-08 17:30:37 | INFO | unicore.checkpoint_utils | copy ./checkpoint57.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:38 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint57.pt ...
# 2024-05-08 17:30:38 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint56.pt
# 2024-05-08 17:30:38 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:39 | INFO | unicore_cli.train | begin validation on "valid" subset
# 2024-05-08 17:30:39 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:40 | INFO | valid | epoch 058 | valid on 'valid' subset | loss 8.806 | valid_mae 1.918 | valid_mse 5.884 | valid_agg_mae 1.818 | valid_agg_mse 5.163 | valid_agg_rmse 2.2722 | bsz 2112 | num_updates 1386 | best_valid_agg_rmse 2.1093
# 2024-05-08 17:30:40 | INFO | unicore_cli.train | early stop since valid performance hasn't improved for last 20 runs
# 2024-05-08 17:30:40 | INFO | unicore.checkpoint_utils | Preparing to save checkpoint for epoch 58 @ 1386 updates
# 2024-05-08 17:30:40 | INFO | unicore.trainer | Saving checkpoint to ./checkpoint58.pt
# 2024-05-08 17:30:40 | INFO | unicore.trainer | Finished saving checkpoint to ./checkpoint58.pt
# 2024-05-08 17:30:40 | INFO | unicore.checkpoint_utils | Saved checkpoint ./checkpoint58.pt (epoch 58 @ 1386 updates, score 2.2722) (writing took 0.4743118390033487 seconds)
# 2024-05-08 17:30:40 | INFO | unicore_cli.train | end of epoch 58 (average epoch stats below)
# 2024-05-08 17:30:40 | INFO | unicore.checkpoint_utils | copy ./checkpoint58.pt to ./save_4CR_0508-24/checkpoint58.pt
# 2024-05-08 17:30:40 | INFO | train | epoch 058 | loss 2.949 | ups 7.96 | bsz 64 | num_updates 1386 | lr 8.08511e-06 | gnorm 307.629 | clip 100 | loss_scale 1 | train_wall 1.54 | gb_free 19.3 | wall 174
# 2024-05-08 17:30:40 | INFO | unicore.checkpoint_utils | copy ./checkpoint58.pt to ./save_4CR_0508-24/checkpoint_last.pt
# 2024-05-08 17:30:41 | INFO | unicore.checkpoint_utils | removing temp file ./checkpoint58.pt ...
# 2024-05-08 17:30:41 | INFO | unicore.checkpoint_utils | removed ./save_4CR_0508-24/checkpoint57.pt
# 2024-05-08 17:30:41 | INFO | unicore.checkpoint_utils | finished async ckp saving.
# 2024-05-08 17:30:41 | INFO | unicore_cli.train | done training in 174.4 seconds

# %% [markdown]
# ## Inference

# %%
results_path=f"./infer_4CR_{date_str}"  # replace to your results path
weight_path=f"./save_4CR_{date_str}/checkpoint_best.pt"  # replace to your ckpt path
# batch_size=64
# task_name='4CR' # data folder name 
# task_num=1
# loss_func='finetune_mse'
# dict_name='dict.txt'
# conf_size=11
# only_polar=0

# !cp ../example_data/molecule/$dict_name $data_path
# !CUDA_VISIBLE_DEVICES="0" python ../unimol/infer.py --user-dir ../unimol $data_path --task-name $task_name --valid-subset test \
       --results-path $results_path \
       --num-workers 6 --ddp-backend=c10d --batch-size $batch_size \
       --task mol_finetune --loss $loss_func --arch unimol_base \
       --classification-head-name $task_name --num-classes $task_num \
       --dict-name $dict_name --conf-size $conf_size \
       --only-polar $only_polar  \
       --path $weight_path  \
       --fp16 --fp16-init-scale 4 --fp16-scale-window 256 \
       --log-interval 50 --log-format simple
# Out:
# cp: cannot stat '../example_data/molecule/dict.txt': No such file or directory
# 2024-05-08 17:30:43 | INFO | unimol.inference | loading model(s) from ./save_4CR_0508-24/checkpoint_best.pt
# 2024-05-08 17:30:43 | INFO | unimol.tasks.unimol_finetune | dictionary: 30 types
# 2024-05-08 17:30:44 | INFO | unimol.inference | Namespace(no_progress_bar=False, log_interval=50, log_format='simple', tensorboard_logdir='', wandb_project='', wandb_name='', seed=1, cpu=False, fp16=True, bf16=False, bf16_sr=False, allreduce_fp32_grad=False, fp16_no_flatten_grads=False, fp16_init_scale=4, fp16_scale_window=256, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir='../unimol', empty_cache_freq=0, all_gather_list_size=16384, suppress_crashes=False, profile=False, ema_decay=-1.0, validate_with_ema=False, loss='finetune_mse_noise', optimizer='adam', lr_scheduler='fixed', task='mol_finetune', num_workers=6, skip_invalid_size_inputs_valid_test=False, batch_size=64, required_batch_size_multiple=1, data_buffer_size=10, train_subset='train', valid_subset='test', validate_interval=1, validate_interval_updates=0, validate_after_updates=0, fixed_validation_seed=None, disable_validation=False, batch_size_valid=64, max_valid_steps=None, curriculum=0, distributed_world_size=1, distributed_rank=0, distributed_backend='nccl', distributed_init_method=None, distributed_port=-1, device_id=0, distributed_no_spawn=False, ddp_backend='c10d', bucket_cap_mb=25, fix_batches_to_gpus=False, find_unused_parameters=False, fast_stat_sync=False, broadcast_buffers=False, nprocs_per_node=1, path='./save_4CR_0508-24/checkpoint_best.pt', quiet=False, model_overrides='{}', results_path='./infer_4CR_0508-24', arch='unimol_base', mode='train', data='./', task_name='4CR_customized', classification_head_name='4CR_customized', num_classes=1, no_shuffle=False, conf_size=11, remove_hydrogen=True, remove_polar_hydrogen=False, max_atoms=256, dict_name='dict.txt', only_polar=0, adam_betas='(0.9, 0.999)', adam_eps=1e-08, weight_decay=0.0, force_anneal=None, lr_shrink=0.1, warmup_updates=0, no_seed_provided=False, encoder_layers=15, encoder_embed_dim=512, encoder_ffn_embed_dim=2048, encoder_attention_heads=64, dropout=0.1, emb_dropout=0.1, attention_dropout=0.1, activation_dropout=0.0, pooler_dropout=0.0, max_seq_len=512, activation_fn='gelu', pooler_activation_fn='tanh', post_ln=False, masked_token_loss=-1.0, masked_coord_loss=-1.0, masked_dist_loss=-1.0, x_norm_loss=-1.0, delta_pair_repr_norm_loss=-1.0, distributed_num_procs=1)
# 2024-05-08 17:30:44 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2024-05-08 17:30:45 | INFO | unimol.inference | Done inference!

# %% [markdown]
# ## Read inference results (.pkl to .csv)

# %%
def get_csv_results(predict_path, csv_path):
    predict = pd.read_pickle(predict_path)
    smi_list, predict_list = [], []
    target_list = []
    for batch in predict:
        sz = batch["bsz"]
        for i in range(sz):
            smi_list.append(batch["smi_name"][i])
            predict_list.append(batch["predict"][i][0].cpu().tolist())
            target_list.append(batch["target"][i][0].cpu().tolist())
    predict_df = pd.DataFrame({"SMILES": smi_list, "predict": predict_list, "target": target_list})
    predict_df = predict_df.groupby("SMILES").mean().reset_index()
    predict_df.to_csv(csv_path,index=False)
    return predict_df

predict_path=f"./infer_4CR_{date_str}/save_4CR_{date_str}_test.out.pkl"  # replace to your results path
csv_path=f"./infer_4CR_{date_str}/4CR_results.csv"
predict_df = get_csv_results(predict_path, csv_path)
predict_df.info(), predict_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SMILES   192 non-null    object
#  1   predict  192 non-null    float64
#  2   target   192 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.6+ KB
# (None,
#                                                SMILES   predict    target
#  0  CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC(C)(C)C... -0.771140 -5.523562
#  1  CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC(C)(C)C... -0.229792 -1.938599
#  2  CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC12C[C@H... -1.202859 -0.823122
#  3  CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC1CCCCC1... -0.870494 -0.665581
#  4  CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NCC(=O)OC... -1.336470 -0.353637)

# %%
predict_df
# Out:
#                                                 SMILES   predict    target
# 0    CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC(C)(C)C... -0.771140 -5.523562
# 1    CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC(C)(C)C... -0.229792 -1.938599
# 2    CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC12C[C@H... -1.202859 -0.823122
# 3    CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NC1CCCCC1... -0.870494 -0.665581
# 4    CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C(=O)NCC(=O)OC... -1.336470 -0.353637
# ..                                                 ...       ...       ...
# 187  CCCCCCCCCCCC(=O)OCCCCCN(C(N(C)C)C(=O)NC(C)(C)C...  0.671852 -0.314109
# 188  CCCCCCCCCCCC(=O)OCCCCCN(C(N(C)C)C(=O)NC12C[C@H... -0.484908 -5.523562
# 189  CCCCCCCCCCCC(=O)OCCCCCN(C(N(C)C)C(=O)NC1CCCCC1...  0.574611  0.605721
# 190  CCCCCCCCCCCC(=O)OCCCCCN(C(N(C)C)C(=O)NCC(=O)OC... -0.889737  1.031027
# 191  CCCCCCCCCCCC(=O)OCCCCCN(C(N(C)C)C(=O)NCCN1CCOC... -0.530950 -1.523562
#
# [192 rows x 3 columns]

# %%
# compute the pearson correlation coefficient between predict and target
from scipy.stats import pearsonr
pearson_corr = pearsonr(predict_df["predict"], predict_df["target"])[0]
print("pearsonr: ", pearson_corr)
# Out:
# pearsonr:  0.8162203674725452

# %%
# check spearman correlation
from scipy.stats import spearmanr
spearman_corr = spearmanr(predict_df["predict"], predict_df["target"])[0]
print("spearmanr: ", spearman_corr)
# Out:
# spearmanr:  0.816609620110225

# %%
# rank the predict_df by predict value
predict_df_sort = predict_df.sort_values(by="predict", ascending=False)
predict_df_sort.to_csv(f"./infer_4CR_{date_str}/4CR_results_sort.csv", index=False)

# visualize the first 10 smiles in the SIMILES column
from rdkit.Chem import Draw

print("Top 10 predicted smiles: ")
img = Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in predict_df_sort["SMILES"].values[:30]], molsPerRow=5, legends=[f"Mol {id}" for id in predict_df_sort["SMILES"].index[:30]])
display(img)
print(predict_df_sort["SMILES"].values[:10])
# Out:
# Top 10 predicted smiles:
# ['CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C1CCNCC1)C(=O)NCCN1CCOCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCCN(C)CCCN)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCCN(C)C)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C1CCN(C)CC1)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(C1CCNCC1)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCN1CCNCC1)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCN(CCN)CCN)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCN1CCNCC1)C(=O)NCCN1CCOCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCC(CCCCCC)C(=O)OCCCCCN(C(CCCN(CC)CC)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC'
#  'CCCCCCCCCCCC(=O)OCCCCCN(C(CCCN(C)CCCN)C(=O)NC1CCCCC1)C(=O)C(CCCCCC)CCCCCCCC']

# %%
print("Least 10 predicted smiles: ")
img = Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in predict_df_sort["SMILES"].values[-10:]], molsPerRow=5, legends=[f"Mol {id}" for id in predict_df_sort["SMILES"].index[-10:]])
display(img)
# Out:
# Least 10 predicted smiles:

# %%
# visualize the first 10 smiles in the SIMILES column
from rdkit.Chem import Draw

print("Top 10 experiment smiles: ")
Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in predict_df.sort_values(by="target", ascending=False)["SMILES"].values[:10]], molsPerRow=5, legends=[f"Mol {id}" for id in predict_df.sort_values(by="target", ascending=False)["SMILES"].index[:10]])
# Out:
# Top 10 experiment smiles:
